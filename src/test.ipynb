# %% [markdown]
# ### This isexample

# %%
print("Hello")
# Out:
# Hello

# %%
class User:
    def __init__(self, name, age):
        self.name = name
        self.age = age

user = User("John", 25)
print(user.name, user.age)
# Out:
# John 25
